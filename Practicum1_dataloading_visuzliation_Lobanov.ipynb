# %% [markdown]
# ## This is the first practical task of Sirius summer school "Applying AI for Med image analysis".
# Practical tasks take form of jupyter notebook with example code in the begging and some tasks in the end. Please, provide your solution in form of python code. Read hints, google a lot, don't hesitate to ask us directyl and most importatly -
# <span style="color:blue">have fun</span>.

# %% [markdown]
# **Topic**: Data loading and visiualization
#
# **To submit**: New version of the notebook, with your code.

# %% [markdown]
# There are several ways to store data for medical imaging:
# - Plain images. (png,jpg)
# - DICOM
# - NIFTI
#
# Plain images and DICOM are commonly used for 2D data, while Nifti and DICOM are used for 3D data.

# %% [markdown]
# DICOM (Digital Imaging and Communications in Medicine) is the standard for the communication and management of medical imaging information and related data. [ref](https://en.wikipedia.org/wiki/DICOM)
#
# For our purpose DICOM is just fancy container with metadata.

# %%
#let's install pydicom, which is a library to operate dicom files and their content
#!pip install pydicom

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %% [markdown]
# [Pydicom documentation](https://pydicom.github.io/pydicom/stable/)

# %%
import pydicom 
dicom_example = pydicom.read_file("data/IM_00020_ano.dcm")

# %% [markdown]
# DICOM holds different kinds of metadata ranging from study details (dose, target area) to patient's personal information.

# %%
print(dicom_example)
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 64
# (0002, 0002) Media Storage SOP Class UID         UI: Digital X-Ray Image Storage - For Presentation
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 144'
# (0008, 0008) Image Type                          CS: 'Oxxxxxxxxxxxxxxx'
# (0008, 0016) SOP Class UID                       UI: Digital X-Ray Image Storage - For Presentation
# (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.2.634.0.63963.2019816.94612.23
# (0008, 0020) Study Date                          DA: '20190816'
# (0008, 0023) Content Date                        DA: '20190816'
# (0008, 0030) Study Time                          TM: '094545'
# (0008, 0033) Content Time                        TM: '094545'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'DX'
# (0008, 0068) Presentation Intent Type            CS: 'FOR PRESENTATION'
# (0008, 0070) Manufacturer                        LO: 'NIPK ELEKTRON'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1010) Station Name                        SH: 'Название станции'
# (0008, 1030) Study Description                   LO: ''
# (0008, 1060) Name of Physician(s) Reading Study  PN: ''
# (0008, 1070) Operators' Name                     PN: 'Лаборант'
# (0008, 1080) Admitting Diagnoses Description     LO: ''
# (0008, 1090) Manufacturer's Model Name           LO: 'KRT'
# (0008, 2218)  Anatomic Region Sequence   1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'T-D3000'
#    (0008, 0102) Coding Scheme Designator            SH: 'SRT'
#    (0008, 0104) Code Meaning                        LO: 'Chest'
#    ---------
# (0009, 0010) Private Creator                     LO: 'EL_PATIENT_ID'
# (0009, 0011) Private Creator                     LO: 'EL_PATIENT'
# (0009, 1102) Private tag data                    LO: ''
# (0009, 1104) Private tag data                    LO: ''
# (0009, 1106) Private tag data                    DT: '00000000000000.0+140766652'
# (0010, 0010) Patient's Name                      PN: 'Шxxxxxx^Гxxxxxxxxx^Сxxxxxxxxxxxx'
# (0010, 0020) Patient ID                          LO: 'auto275682'
# (0010, 0021) Issuer of Patient ID                LO: ''
# (0010, 0030) Patient's Birth Date                DA: '19000101'
# (0010, 0040) Patient's Sex                       CS: 'F'
# (0010, 1000) Other Patient IDs                   LO: ''
# (0010, 1001) Other Patient Names                 PN: ''
# (0010, 1020) Patient's Size                      DS: None
# (0010, 1030) Patient's Weight                    DS: None
# (0010, 1040) Patient's Address                   LO: ''
# (0010, 2152) Region of Residence                 LO: ''
# (0010, 2154) Patient's Telephone Numbers         SH: ''
# (0010, 21c0) Pregnancy Status                    US: 0
# (0010, 4000) Patient Comments                    LT: ''
# (0011, 0010) Private Creator                     LO: 'EL_PATIENT_DEMOGRAPHIC_ID'
# (0011, 0011) Private Creator                     LO: 'EL_PATIENT_DEM'
# (0011, 1101) Private tag data                    LO: ''
# (0011, 1102) Private tag data                    LO: ''
# (0011, 1104) Private tag data                    LO: ''
# (0011, 1105) Private tag data                    LO: ''
# (0011, 1106) Private tag data                    LO: ''
# (0011, 1112) Private tag data                    LO: 'auto275682'
# (0018, 0010) Contrast/Bolus Agent                LO: ''
# (0018, 0060) KVP                                 DS: "100.0"
# (0018, 1000) Device Serial Number                LO: '12RTGPD3535'
# (0018, 1020) Software Versions                   LO: 'PICKSYS Лаборант Build 33, Version 2.0.0.0'
# (0018, 1050) Spatial Resolution                  DS: None
# (0018, 1152) Exposure                            IS: "1"
# (0018, 1153) Exposure in uAs                     IS: "1400"
# (0018, 1155) Radiation Setting                   CS: 'GR'
# (0018, 115e) Image and Fluoroscopy Area Dose Pro DS: "6.0"
# (0018, 1508) Positioner Type                     CS: ''
# (0018, 5100) Patient Position                    CS: ''
# (0018, 5101) View Position                       CS: 'AP'
# (0018, 7004) Detector Type                       CS: 'DIRECT'
# (0020, 000d) Study Instance UID                  UI: 1.2.826.0.1.3680043.2.634.0.63046.20190816.94337.46
# (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.3680043.2.634.0.48182.20190816.94543.47
# (0020, 0010) Study ID                            SH: '276306'
# (0020, 0011) Series Number                       IS: "0"
# (0020, 0013) Instance Number                     IS: "0"
# (0020, 0020) Patient Orientation                 CS: ['L', 'H']
# (0020, 0062) Image Laterality                    CS: 'B'
# (0020, 4000) Image Comments                      LT: ''
# (0021, 0011) Private Creator                     LO: 'EL_STUDY'
# (0021, 1109) Private tag data                    LO: 'легкие диагн'
# (0021, 1120) Private tag data                    IS: "1"
# (0021, 1122) Private tag data                    FL: 0.060600001364946365
# (0021, 1123) Private tag data                    IS: "1"
# (0021, 1124) Private tag data                    LT: ''
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME1'
# (0028, 0010) Rows                                US: 2341
# (0028, 0011) Columns                             US: 2420
# (0028, 0030) Pixel Spacing                       DS: [0.133, 0.133]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0301) Burned In Annotation                CS: 'NO'
# (0028, 1040) Pixel Intensity Relationship        CS: 'LIN'
# (0028, 1041) Pixel Intensity Relationship Sign   SS: 1
# (0028, 1050) Window Center                       DS: "14269.07"
# (0028, 1051) Window Width                        DS: "20197.7"
# (0028, 1052) Rescale Intercept                   DS: "0.0"
# (0028, 1053) Rescale Slope                       DS: "1.0"
# (0028, 1054) Rescale Type                        LO: 'US'
# (0028, 2110) Lossy Image Compression             CS: '00'
# (0029, 0010) Private Creator                     LO: 'EL_IMAGE'
# (0029, 1000) Private tag data                    IS: "34175"
# (0029, 1107) Private tag data                    LO: 'прямая'
# (0029, 1120) Private tag data                    FD: 100.0
# (0029, 1121) Private tag data                    FD: 8.0
# (0029, 1122) Private tag data                    FD: 160.0
# (0029, 1123) Private tag data                    FD: 50.0
# (0029, 1124) Private tag data                    IS: "1"
# (0029, 1125) Private tag data                    IS: "5"
# (0029, 1126) Private tag data                    IS: "1"
# (0029, 1127) Private tag data                    IS: "20198"
# (0029, 1128) Private tag data                    IS: "14269"
# (0029, 1129) Private tag data                    IS: "1"
# (0029, 1130) Private tag data                    IS: "3073"
# (0029, 1131) Private tag data                    IS: "3072"
# (0031, 0010) Private Creator                     LO: 'EL_XRAY_ID'
# (0031, 0011) Private Creator                     LO: 'EL_XRAY'
# (0031, 1101) Private tag data                    DS: "0.0606"
# (0035, 0011) Private Creator                     LO: 'EL_PRESENTATION'
# (0035, 1102) Private tag data                    DS: "1.0"
# (0035, 1104) Private tag data                    IS: "90"
# (0035, 1105) Private tag data                    LO: 'Отражение не задано'
# (0040, 0302) Entrance Dose                       US: 60
# (0055, 1106) Private tag data                    LO: ''
# (0055, 1107) Private tag data                    IS: "0"
# (2050, 0020) Presentation LUT Shape              CS: 'INVERSE'
# (7fe0, 0010) Pixel Data                          OW: Array of 11330440 elements

# %% [markdown]
# The most common vizualization library is matplotlib. It allows to draw images and create complex plots.

# %%
#!pip install matplotlib

# %% [markdown]
# Pixel values are stored inside (7fe0, 0010) DICOM tag. We can access it using .pixel_array field
# Let's look at our image using matplotlib function .imshow()

# %%
from matplotlib import pyplot as plt
import matplotlib
import numpy as np

plt.imshow(dicom_example.pixel_array,cmap="bone")

# %% [markdown]
# Let's look at histogram of pixel values.
# We will apply plt.hist to "flattened" version of x-ray
# https://en.wikipedia.org/wiki/Cumulative_distribution_function
# https://en.wikipedia.org/wiki/Histogram

# %%
def create_histogram_and_cdf(dicom):
    """
    Creates histogram and CDF
    """
    fig, (histogram, cdf_plot) = plt.subplots(1, 2,figsize=(10,5))

    histogram.hist(dicom.ravel(),bins=256)
    
    cdf_plot.hist(dicom.ravel(),bins=100, cumulative=True, label='CDF',
         histtype='bar', alpha=0.8, color='k',density=True)
    plt.show()

create_histogram_and_cdf(dicom_example.pixel_array)

# %% [markdown]
# #### We see 2 small outliers on left and right side of histogram. Let's drop them and see what happens.

# %%
img_cpy = dicom_example.pixel_array.copy()
img_cpy[dicom_example.pixel_array == dicom_example.pixel_array.min()] = dicom_example.pixel_array.mean()-dicom_example.pixel_array.std()
img_cpy[dicom_example.pixel_array == dicom_example.pixel_array.max()] = dicom_example.pixel_array.mean()+dicom_example.pixel_array.std()

# %%
plt.imshow(img_cpy,cmap="bone")
plt.show()
create_histogram_and_cdf(img_cpy)

# %% [markdown]
# ### There are a lot of other tricks to manipulate image histogram to make it look nicer. Good slides about image preprocessing: https://docplayer.ru/66503788-Osnovy-obrabotki-izobrazheniy-anton-konushin.html

# %% [markdown]
# ### Actual values of pixel do not matter, their relative distribution is much more important, hence we can convert our image to proper uint8

# %%
img = img_cpy.copy()
img = ((img-img.min()) / (img.max()-img.min()) * 255).astype(np.uint8)
print("Original image maximum {}".format(img_cpy.max()))
print("New image maximum {}".format(img.max()))
plt.imshow(img,cmap="bone")
create_histogram_and_cdf(img)
plt.show()
plt.imshow(img_cpy,cmap="bone")
create_histogram_and_cdf(img_cpy)

##literally the same image
# Out:
# Original image maximum 22103
# New image maximum 255

# %% [markdown]
# ### Functions which transforms colors to new colors is called Color mapping function. In radiology this functions also called LUT (look up table).
# ### Radiologists use different LUTs to highlate certain tissue. Let's apply one and see a result.

# %%
from pydicom.pixel_data_handlers.util import apply_color_lut
plt.imshow(apply_color_lut(img,palette="PET_20_STEP"),cmap="bone")

# %%
create_histogram_and_cdf(apply_color_lut(img,palette="PET_20_STEP"))
create_histogram_and_cdf(img)

# %% [markdown]
# #### We could call any function f(pixel_array) -> pixel_array LUT.
# #### For example threholding could be seen as particular example of LUT

# %%
def thresholding(image):
    return image<90
plt.imshow(thresholding(img),cmap="bone")
create_histogram_and_cdf(thresholding(img).astype(np.uint8))

# %% [markdown]
# ## **Tasks:**
# - Given: img variable with image data in it
# - Do: Think about any function f(img)->new_image. Apply it and visualize the result.
# - Hints: https://pydicom.github.io/pydicom/dev/reference/generated/pydicom.pixel_data_handlers.util.html#pydicom.pixel_data_handlers.util.apply_color_lut

# %%
def contrast(img):
  return img*2
plt.imshow(contrast(img),cmap="bone")
create_histogram_and_cdf(contrast(img).astype(np.uint8))

# %% [markdown]
# ## **Task 2:**
# - Sometimes data is broken and your job is to recover useful information
# - Given: Data with broken distribution
# - Do: Fix distribution any way you see fit and visualize correct x-ray.

# %%
broken_file = pydicom.read_file("data/broken_file.dcm")
broken_pixel = broken_file.pixel_array

# %%
broken_pixel_cpy = broken_pixel.copy()
broken_pixel_cpy[broken_pixel == broken_pixel.min()] = broken_pixel.mean() - broken_pixel.std()
broken_pixel_cpy[broken_pixel == broken_pixel.max()] = broken_pixel.mean() + broken_pixel.std()

plt.imshow(broken_pixel_cpy,cmap="bone")
create_histogram_and_cdf(broken_pixel_cpy.astype(np.uint8))
